# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn import datasets, metrics
from sklearn.model_selection import train_test_split

# %% [markdown]
# # LogisticRegression

# %%
x,y=datasets.load_breast_cancer(return_X_y=True)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=1,stratify=y)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
LG = LogisticRegression()
LG.fit(x_train,y_train)
y_predct = LG.predict(x_test)

# %%
metrics.mean_squared_error(y_test,y_predct)
# Out:
# 0.04093567251461988

# %%
metrics.accuracy_score(y_test,y_predct)
# Out:
# 0.9590643274853801

# %%
print(metrics.classification_report(y_test,y_predct))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.94        64
#            1       0.95      0.98      0.97       107
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.95      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %%
sns.heatmap(metrics.confusion_matrix(y_test,y_predct),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
x,y=datasets.load_breast_cancer(return_X_y=True)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=1,stratify=y)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(x_train,y_train)
y_predct = knn.predict(x_test)

# %%
metrics.accuracy_score(y_test,y_predct)
# Out:
# 0.9707602339181286

# %%
print(metrics.classification_report(y_test,y_predct))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        64
#            1       0.96      1.00      0.98       107
#
#     accuracy                           0.97       171
#    macro avg       0.98      0.96      0.97       171
# weighted avg       0.97      0.97      0.97       171

# %%
sns.heatmap(metrics.confusion_matrix(y_test,y_predct),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # DecisionTree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
x,y=datasets.load_breast_cancer(return_X_y=True)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=1,stratify=y)

# %%
DT = DecisionTreeClassifier()
DT.fit(x_train,y_train)
y_predct = DT.predict(x_test)

# %%
metrics.accuracy_score(y_test,y_predct)
# Out:
# 0.9473684210526315

# %%
from sklearn import tree
plt.figure(figsize=(20,10),dpi=180)
tree.plot_tree(DT);

# %%
print(metrics.classification_report(y_test,y_predct))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        64
#            1       0.96      0.95      0.96       107
#
#     accuracy                           0.95       171
#    macro avg       0.94      0.95      0.94       171
# weighted avg       0.95      0.95      0.95       171

# %%
sns.heatmap(metrics.confusion_matrix(y_test,y_predct),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Ranodom Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
x,y=datasets.load_breast_cancer(return_X_y=True)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=1,stratify=y)

# %%
RF = RandomForestClassifier(random_state=1,max_depth=5,n_jobs=-1) 
RF.fit(x_train,y_train)
y_predct = RF.predict(x_test)

# %%
metrics.accuracy_score(y_test,y_predct)
# Out:
# 0.9590643274853801

# %%
print(metrics.classification_report(y_test,y_predct))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94        64
#            1       0.96      0.97      0.97       107
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.95      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %%
metrics.plot_confusion_matrix(svc,x_test,y_test)

# %% [markdown]
# # C-Support Vector Classification.

# %%
from sklearn import svm

# %%
x,y=datasets.load_breast_cancer(return_X_y=True)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=1,stratify=y)

# %%
svc = svm.SVC(kernel='linear')
svc.fit(x_train,y_train)
y_predct = svc.predict(x_test)

# %%
metrics.accuracy_score(y_test,y_predct)
# Out:
# 0.9649122807017544

# %%
print(metrics.classification_report(y_test,y_predct))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95        42
#            1       0.96      0.99      0.97        72
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114

# %%
sns.heatmap(metrics.confusion_matrix(y_test,y_predct),annot=True)
# Out:
# <AxesSubplot:>

# %%
metrics.plot_confusion_matrix(svc,x_test,y_test)

# %% [markdown]
# # Epsilon-Support Vector Regression.

# %%
x,y=datasets.fetch_california_housing(return_X_y=True)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
svr = svm.SVR()
svr.fit(x_train,y_train)
y_predct = svr.predict(x_test)

# %%
metrics.mean_squared_error(y_test,y_predct)
# Out:
# 0.35016266757637693

# %%
metrics.r2_score(y_test,y_predct)
# Out:
# 0.733044818224438
