# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('credit-default-dataset.xls')

# %%
df.head()
# Out:
#   Unnamed: 0         X1      X2          X3        X4   X5     X6     X7  \
# 0         ID  LIMIT_BAL     SEX   EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2
# 1          1      20000  Female  university   married   24      2      2
# 2          2     120000  Female  university    single   26     -1      2
# 3          3      90000  Female  university    single   34      0      0
# 4          4      50000  Female  university   married   37      0      0
#
#       X8     X9  ...        X15        X16        X17       X18       X19  \
# 0  PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2
# 1     -1     -1  ...          0          0          0         0       689
# 2      0      0  ...       3272       3455       3261         0      1000
# 3      0      0  ...      14331      14948      15549      1518      1500
# 4      0      0  ...      28314      28959      29547      2000      2019
#
#         X20       X21       X22       X23                           Y
# ...

# %%
df.shape
# Out:
# (30001, 25)

# %%
header = df.iloc[0]
df.columns = header
df.head()
# Out:
# 0  ID  LIMIT_BAL     SEX   EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0  ID  LIMIT_BAL     SEX   EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 1   1      20000  Female  university   married   24      2      2     -1
# 2   2     120000  Female  university    single   26     -1      2      0
# 3   3      90000  Female  university    single   34      0      0      0
# 4   4      50000  Female  university   married   37      0      0      0
#
# 0  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 1     -1  ...          0          0          0         0       689         0
# 2      0  ...       3272       3455       3261         0      1000      1000
# 3      0  ...      14331      14948      15549      1518      1500      1000
# 4      0  ...      28314      28959      29547      2000      2019      1200
#
# 0  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.drop(0,inplace= True)

# %%
df.head()
# Out:
# 0 ID LIMIT_BAL     SEX   EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4  ...  \
# 1  1     20000  Female  university  married  24     2     2    -1    -1  ...
# 2  2    120000  Female  university   single  26    -1     2     0     0  ...
# 3  3     90000  Female  university   single  34     0     0     0     0  ...
# 4  4     50000  Female  university  married  37     0     0     0     0  ...
# 5  5     50000    Male  university  married  57    -1     0    -1     0  ...
#
# 0 BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3 PAY_AMT4 PAY_AMT5  \
# 1         0         0         0        0      689        0        0        0
# 2      3272      3455      3261        0     1000     1000     1000        0
# 3     14331     14948     15549     1518     1500     1000     1000     1000
# 4     28314     28959     29547     2000     2019     1200     1100     1069
# 5     20940     19146     19131     2000    36681    10000     9000      689
#
# 0 PAY_AMT6 default payment next month
# ...

# %%
df.reset_index(inplace= True,drop=True)

# %%
df.drop('index',axis=1,inplace=True)

# %%
df.head()
# Out:
# 0 ID LIMIT_BAL     SEX   EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4  ...  \
# 0  1     20000  Female  university  married  24     2     2    -1    -1  ...
# 1  2    120000  Female  university   single  26    -1     2     0     0  ...
# 2  3     90000  Female  university   single  34     0     0     0     0  ...
# 3  4     50000  Female  university  married  37     0     0     0     0  ...
# 4  5     50000    Male  university  married  57    -1     0    -1     0  ...
#
# 0 BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3 PAY_AMT4 PAY_AMT5  \
# 0         0         0         0        0      689        0        0        0
# 1      3272      3455      3261        0     1000     1000     1000        0
# 2     14331     14948     15549     1518     1500     1000     1000     1000
# 3     28314     28959     29547     2000     2019     1200     1100     1069
# 4     20940     19146     19131     2000    36681    10000     9000      689
#
# 0 PAY_AMT6 default payment next month
# ...

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df.head()
# Out:
#   id limit_bal     sex   education marriage age pay_0 pay_2 pay_3 pay_4  ...  \
# 0  1     20000  Female  university  married  24     2     2    -1    -1  ...
# 1  2    120000  Female  university   single  26    -1     2     0     0  ...
# 2  3     90000  Female  university   single  34     0     0     0     0  ...
# 3  4     50000  Female  university  married  37     0     0     0     0  ...
# 4  5     50000    Male  university  married  57    -1     0    -1     0  ...
#
#   bill_amt4 bill_amt5 bill_amt6 pay_amt1 pay_amt2 pay_amt3 pay_amt4 pay_amt5  \
# 0         0         0         0        0      689        0        0        0
# 1      3272      3455      3261        0     1000     1000     1000        0
# 2     14331     14948     15549     1518     1500     1000     1000     1000
# 3     28314     28959     29547     2000     2019     1200     1100     1069
# 4     20940     19146     19131     2000    36681    10000     9000      689
#
#   pay_amt6 default payment next month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          30000 non-null  object
#  1   limit_bal                   30000 non-null  object
#  2   sex                         30000 non-null  object
#  3   education                   30000 non-null  object
#  4   marriage                    30000 non-null  object
#  5   age                         30000 non-null  object
#  6   pay_0                       30000 non-null  object
#  7   pay_2                       30000 non-null  object
#  8   pay_3                       30000 non-null  object
#  9   pay_4                       30000 non-null  object
#  10  pay_5                       30000 non-null  object
#  11  pay_6                       30000 non-null  object
#  12  bill_amt1                   30000 non-null  object
# ...

# %%
df = df.apply(pd.to_numeric, errors = 'ignore')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          30000 non-null  int64
#  1   limit_bal                   30000 non-null  int64
#  2   sex                         30000 non-null  object
#  3   education                   30000 non-null  object
#  4   marriage                    30000 non-null  object
#  5   age                         30000 non-null  int64
#  6   pay_0                       30000 non-null  int64
#  7   pay_2                       30000 non-null  int64
#  8   pay_3                       30000 non-null  int64
#  9   pay_4                       30000 non-null  int64
#  10  pay_5                       30000 non-null  int64
#  11  pay_6                       30000 non-null  int64
#  12  bill_amt1                   30000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                            0
# limit_bal                     0
# sex                           0
# education                     0
# marriage                      0
# age                           0
# pay_0                         0
# pay_2                         0
# pay_3                         0
# pay_4                         0
# pay_5                         0
# pay_6                         0
# bill_amt1                     0
# bill_amt2                     0
# bill_amt3                     0
# bill_amt4                     0
# bill_amt5                     0
# bill_amt6                     0
# pay_amt1                      0
# pay_amt2                      0
# pay_amt3                      0
# pay_amt4                      0
# pay_amt5                      0
# pay_amt6                      0
# default payment next month    0
# dtype: int64

# %%
df.rename(columns={'default payment next month':'Y'},inplace = True)

# %%
df.head()
# Out:
#    id  limit_bal     sex   education marriage  age  pay_0  pay_2  pay_3  \
# 0   1      20000  Female  university  married   24      2      2     -1
# 1   2     120000  Female  university   single   26     -1      2      0
# 2   3      90000  Female  university   single   34      0      0      0
# 3   4      50000  Female  university  married   37      0      0      0
# 4   5      50000    Male  university  married   57     -1      0     -1
#
#    pay_4  ...  bill_amt4  bill_amt5  bill_amt6  pay_amt1  pay_amt2  pay_amt3  \
# 0     -1  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    pay_amt4  pay_amt5  pay_amt6    Y
# ...

# %%
df['Y'].value_counts()
# Out:
# No     23364
# Yes     6636
# Name: Y, dtype: int64

# %%
df['Y'].dtypes
# Out:
# dtype('O')

# %%
for i in df.columns:
    if df[i].dtypes == object:
        print("Column:",i)
        print(df[i].value_counts())
        print('-'*30)
# Out:
# Column: sex
# Female    18112
# Male      11888
# Name: sex, dtype: int64
# ------------------------------
# Column: education
# university         14030
# graduate school    10585
# high school         4917
# 5                    280
# others               123
# 6                     51
# 0                     14
# Name: education, dtype: int64
# ------------------------------
# Column: marriage
# single     15964
# married    13659
# others       323
# 0             54
# Name: marriage, dtype: int64
# ------------------------------
# Column: Y
# No     23364
# Yes     6636
# Name: Y, dtype: int64
# ------------------------------

# %%
df['education'] = df['education'].apply(lambda x: 'others' if x == 'other' else x)

# %%
df['education'].value_counts()
# Out:
# university         14030
# graduate school    10585
# high school         4917
# others               468
# Name: education, dtype: int64

# %%
df['marriage'] = df['marriage'].apply(lambda x: 'others' if x == 0 else x)

# %%
df['marriage'].value_counts()
# Out:
# single     15964
# married    13659
# others       377
# Name: marriage, dtype: int64

# %%
df.describe()
# Out:
#                  id       limit_bal           age         pay_0         pay_2  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667     35.485500     -0.016700     -0.133767
# std     8660.398374   129747.661567      9.217904      1.123802      1.197186
# min        1.000000    10000.000000     21.000000     -2.000000     -2.000000
# 25%     7500.750000    50000.000000     28.000000     -1.000000     -1.000000
# 50%    15000.500000   140000.000000     34.000000      0.000000      0.000000
# 75%    22500.250000   240000.000000     41.000000      0.000000      0.000000
# max    30000.000000  1000000.000000     79.000000      8.000000      8.000000
#
#               pay_3         pay_4         pay_5         pay_6      bill_amt1  \
# count  30000.000000  30000.000000  30000.000000  30000.000000   30000.000000
# mean      -0.166200     -0.220667     -0.266200     -0.291100   51223.330900
# ...

# %%
# remove outlier using IQR
def remove_outlier(df):
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)
    IQR = Q3-Q1
    df[(df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))] = np.nan
    df.dropna(inplace= True)
    return df

df = remove_outlier(df)
# Out:
# C:\Users\Sherif\AppData\Local\Temp\ipykernel_13224\101394692.py:6: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df[(df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))] = np.nan

# %%
df.quantile(0.75)
# Out:
# id            22472.0
# limit_bal    210000.0
# age              41.0
# pay_0             0.0
# pay_2             0.0
# pay_3             0.0
# pay_4             0.0
# pay_5             0.0
# pay_6             0.0
# bill_amt1     45268.0
# bill_amt2     40710.0
# bill_amt3     34855.0
# bill_amt4     28894.0
# bill_amt5     26341.0
# bill_amt6     24612.0
# pay_amt1       2625.0
# pay_amt2       2500.0
# pay_amt3       2003.0
# pay_amt4       2000.0
# pay_amt5       2000.0
# pay_amt6       2000.0
# Name: 0.75, dtype: float64

# %%
df.shape
# Out:
# (11489, 25)

# %%
df.head()
# Out:
#     id  limit_bal     sex        education marriage   age  pay_0  pay_2  \
# 2    3    90000.0  Female       university   single  34.0    0.0    0.0
# 3    4    50000.0  Female       university  married  37.0    0.0    0.0
# 5    6    50000.0    Male  graduate school   single  37.0    0.0    0.0
# 7    8   100000.0  Female       university   single  23.0    0.0   -1.0
# 14  15   250000.0    Male  graduate school   single  29.0    0.0    0.0
#
#     pay_3  pay_4  ...  bill_amt4  bill_amt5  bill_amt6  pay_amt1  pay_amt2  \
# 2     0.0    0.0  ...    14331.0    14948.0    15549.0    1518.0    1500.0
# 3     0.0    0.0  ...    28314.0    28959.0    29547.0    2000.0    2019.0
# 5     0.0    0.0  ...    19394.0    19619.0    20024.0    2500.0    1815.0
# 7    -1.0    0.0  ...      221.0     -159.0      567.0     380.0     601.0
# 14    0.0    0.0  ...    59696.0    56875.0    55512.0    3000.0    3000.0
#
#     pay_amt3  pay_amt4  pay_amt5  pay_amt6   Y
# ...

# %%
df.isnull().sum()
# Out:
# id           0
# limit_bal    0
# sex          0
# education    0
# marriage     0
# age          0
# pay_0        0
# pay_2        0
# pay_3        0
# pay_4        0
# pay_5        0
# pay_6        0
# bill_amt1    0
# bill_amt2    0
# bill_amt3    0
# bill_amt4    0
# bill_amt5    0
# bill_amt6    0
# pay_amt1     0
# pay_amt2     0
# pay_amt3     0
# pay_amt4     0
# pay_amt5     0
# pay_amt6     0
# Y            0
# dtype: int64

# %%
df.to_excel('New-Credit.xlsx')
